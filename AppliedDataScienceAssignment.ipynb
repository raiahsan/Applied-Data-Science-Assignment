# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("datasetofworldgdp.csv", encoding='latin1')

# %%
data
# Out:
#            country_name                      indicator_name  1980  1981  1982  \
# 0           Afghanistan  Annual GDP growth (percent change)   NaN   NaN   NaN
# 1               Albania  Annual GDP growth (percent change)   2.7   5.7   2.9
# 2               Algeria  Annual GDP growth (percent change)  -5.4   3.0   6.4
# 3               Andorra  Annual GDP growth (percent change)   NaN   NaN   NaN
# 4                Angola  Annual GDP growth (percent change)   2.4  -4.4   0.0
# ..                  ...                                 ...   ...   ...   ...
# 191             Vietnam  Annual GDP growth (percent change)  -3.5   5.8   8.2
# 192  West Bank and Gaza  Annual GDP growth (percent change)   NaN   NaN   NaN
# 193               Yemen  Annual GDP growth (percent change)   NaN   NaN   NaN
# 194              Zambia  Annual GDP growth (percent change)   3.9   6.6  -2.9
# 195            Zimbabwe  Annual GDP growth (percent change)   NaN   NaN   NaN
#
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# check the dataset

# %%
data.head()
# Out:
#   country_name                      indicator_name  1980  1981  1982  1983  \
# 0  Afghanistan  Annual GDP growth (percent change)   NaN   NaN   NaN   NaN
# 1      Albania  Annual GDP growth (percent change)   2.7   5.7   2.9   1.1
# 2      Algeria  Annual GDP growth (percent change)  -5.4   3.0   6.4   5.4
# 3      Andorra  Annual GDP growth (percent change)   NaN   NaN   NaN   NaN
# 4       Angola  Annual GDP growth (percent change)   2.4  -4.4   0.0   4.2
#
#    1984  1985  1986  1987  ...  2015  2016  2017  2018  2019  2020  2021  \
# 0   NaN   NaN   NaN   NaN  ...   1.0   2.2   2.6   1.2   3.9  -2.4 -20.7
# 1   2.0  -1.5   5.6  -0.8  ...   2.2   3.3   3.8   4.0   2.1  -3.3   8.9
# 2   5.6   5.6  -0.2  -0.7  ...   3.7   3.2   1.4   1.2   1.0  -5.1   3.4
# 3   NaN   NaN   NaN   NaN  ...   1.4   3.7   0.3   1.6   2.0 -11.2   8.3
# 4   6.0   3.5   2.9   4.1  ...   0.9  -2.6  -0.2  -1.3  -0.7  -5.6   1.2
#
#    2022  2023  2024
# 0   NaN   NaN   NaN
# 1   4.8   3.6   3.3
# ...

# %%
data.tail()
# Out:
#            country_name                      indicator_name  1980  1981  1982  \
# 191             Vietnam  Annual GDP growth (percent change)  -3.5   5.8   8.2
# 192  West Bank and Gaza  Annual GDP growth (percent change)   NaN   NaN   NaN
# 193               Yemen  Annual GDP growth (percent change)   NaN   NaN   NaN
# 194              Zambia  Annual GDP growth (percent change)   3.9   6.6  -2.9
# 195            Zimbabwe  Annual GDP growth (percent change)   NaN   NaN   NaN
#
#      1983  1984  1985  1986  1987  ...  2015  2016  2017  2018  2019  2020  \
# 191   7.1   8.4   5.6   3.4   2.5  ...   7.0   6.7   6.9   7.5   7.4   2.9
# 192   NaN   NaN   NaN   NaN   NaN  ...   3.7   8.9   1.4   1.2   1.4 -11.3
# 193   NaN   NaN   NaN   NaN   NaN  ... -28.0  -9.4  -5.1   0.8   2.1  -8.5
# 194  -1.1  -1.7   1.2   1.7   1.5  ...   2.9   3.8   3.5   4.0   1.4  -2.8
# 195   NaN   NaN   NaN   NaN   NaN  ...   1.8   0.8   5.2   5.0  -6.3  -7.8
#
#      2021  2022  2023  2024
# ...

# %%
data.shape
# Out:
# (196, 47)

# %%
# check the number total number of row and coloum in the data set

# %%
print('Number of Columns',data.shape[0])
print('Number of Rows',data.shape[1])
# Out:
# Number of Columns 196
# Number of Rows 47

# %%
# returns the number of missing values in the dataset.

# %%
data.isnull().sum()
# Out:
# country_name       0
# indicator_name     0
# 1980              55
# 1981              51
# 1982              49
# 1983              49
# 1984              49
# 1985              49
# 1986              48
# 1987              47
# 1988              46
# 1989              46
# 1990              46
# 1991              38
# 1992              36
# 1993              25
# 1994              23
# 1995              21
# 1996              18
# 1997              18
# 1998              15
# 1999              12
# 2000              12
# 2001               5
# 2002               4
# 2003               3
# 2004               3
# 2005               2
# 2006               2
# 2007               2
# 2008               2
# 2009               2
# 2010               2
# 2011               3
# 2012               1
# 2013               1
# 2014               1
# 2015               1
# 2016               1
# 2017               1
# 2018               1
# 2019               1
# 2020               2
# ...

# %%
# prints information about the DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 47 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_name    196 non-null    object
#  1   indicator_name  196 non-null    object
#  2   1980            141 non-null    float64
#  3   1981            145 non-null    float64
#  4   1982            147 non-null    float64
#  5   1983            147 non-null    float64
#  6   1984            147 non-null    float64
#  7   1985            147 non-null    float64
#  8   1986            148 non-null    float64
#  9   1987            149 non-null    float64
#  10  1988            150 non-null    float64
#  11  1989            150 non-null    float64
#  12  1990            150 non-null    float64
#  13  1991            158 non-null    float64
#  14  1992            160 non-null    float64
#  15  1993            171 non-null    float64
#  16  1994            173 non-null    float64
# ...

# %%
data.describe()
# Out:
#              1980        1981        1982        1983        1984        1985  \
# count  141.000000  145.000000  147.000000  147.000000  147.000000  147.000000
# mean     3.113475    2.677931    1.320408    1.832653    4.196599    3.125170
# std      5.450062    5.582481    6.421997    5.492974    6.771237    4.807982
# min    -21.600000  -20.000000  -36.800000  -16.100000  -16.800000  -13.000000
# 25%      0.000000    0.100000   -1.100000   -1.350000    1.650000    0.850000
# 50%      3.400000    2.900000    1.800000    2.400000    4.100000    3.500000
# 75%      6.100000    5.700000    4.100000    4.650000    6.200000    5.600000
# max     18.800000   17.100000   23.200000   22.700000   44.500000   24.300000
#
#              1986        1987        1988        1989  ...        2015  \
# count  148.000000  149.000000  150.000000  150.000000  ...  195.000000
# mean     3.728378    3.718792    4.114000    3.396667  ...    2.585641
# ...

# %%
# calculates the relationship between each column in your data set

# %%
data.corr
# Out:
# <bound method DataFrame.corr of            country_name                      indicator_name  1980  1981  1982  \
# 0           Afghanistan  Annual GDP growth (percent change)   NaN   NaN   NaN
# 1               Albania  Annual GDP growth (percent change)   2.7   5.7   2.9
# 2               Algeria  Annual GDP growth (percent change)  -5.4   3.0   6.4
# 3               Andorra  Annual GDP growth (percent change)   NaN   NaN   NaN
# 4                Angola  Annual GDP growth (percent change)   2.4  -4.4   0.0
# ..                  ...                                 ...   ...   ...   ...
# 191             Vietnam  Annual GDP growth (percent change)  -3.5   5.8   8.2
# 192  West Bank and Gaza  Annual GDP growth (percent change)   NaN   NaN   NaN
# 193               Yemen  Annual GDP growth (percent change)   NaN   NaN   NaN
# 194              Zambia  Annual GDP growth (percent change)   3.9   6.6  -2.9
# 195            Zimbabwe  Annual GDP growth (percent change)   NaN   NaN   NaN
#
# ...

# %%
cat = []
num = []
for column in data.columns:
    if data[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
num
# Out:
# ['country_name',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2024']

# %%
row_x
# Out:
# ['indicator_name']

# %%
data.columns
# Out:
# Index(['country_name', 'indicator_name', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')

# %%
data.nunique()
# Out:
# country_name      196
# indicator_name      1
# 1980              104
# 1981               95
# 1982               99
# 1983               98
# 1984               97
# 1985               97
# 1986               94
# 1987               99
# 1988              101
# 1989               95
# 1990              102
# 1991              114
# 1992              107
# 1993              118
# 1994              109
# 1995              106
# 1996               90
# 1997              105
# 1998               99
# 1999              100
# 2000               93
# 2001              105
# 2002              100
# 2003              110
# 2004              102
# 2005              104
# 2006              100
# 2007              107
# 2008              107
# 2009              126
# 2010              104
# 2011              100
# 2012              112
# 2013              100
# 2014               90
# 2015               99
# 2016               90
# 2017               95
# 2018               80
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Use Seaborn countplot to visualize the data

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='2024', data=data, palette=['Pink', 'skyBlue', 'Blue'])
plt.title('Count of Values for Each Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
data['2024'].value_counts()
# Out:
# 2024
# 5.0    9
# 3.0    9
# 2.7    8
# 3.3    7
# 3.2    7
#       ..
# 5.6    1
# 4.4    1
# 6.6    1
# 4.6    1
# 5.8    1
# Name: count, Length: 67, dtype: int64

# %%
data['2024'].value_counts().plot(kind='pie', autopct="%5.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data['2024'].unique()
# Out:
# array([ nan,  3.3,  3.1,  1.5,  5.4,  2.8,  5. ,  1.2,  0.8,  2.5,  1.8,
#         3.6,  6. ,  3.9,  1.3,  0.9,  3. ,  6.3,  4.1,  3.5,  3.2,  6.4,
#         4.5,  6.1,  4.2,  1.6,  3.7,  2. ,  4.7,  4.4,  2.6,  2.7,  2.3,
#         6.6,  1.4,  4.6,  5.2,  1.9, -5.5,  2.4,  6.2,  1. ,  4.8,  3.8,
#         5.6, 26.6,  2.9,  1.7,  0.7,  5.3,  2.2,  4. ,  4.3,  7.5, 27.2,
#         2.1,  1.1, 11.1, 12.4,  5.9, -0.2,  7. ,  8.8,  0.3,  0.6,  5.7,
#         5.5,  5.8])

# %%
# Histogram of year

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['2024'], bins=20, kde=True, color='brown')
# Out:
# <Axes: xlabel='2024', ylabel='Count'>

# %%
data['2023'].unique()
# Out:
# array([  nan,   3.6,   3.8,   2.1,   1.3,   5.6,  -2.5,   7. ,   2.3,
#          1.8,   0.1,   2.5,   4.3,   2.7,   6. ,   4.5,   1.6,   1. ,
#          4. ,   5.5,   5.3,   2. ,   3.1,  -0.8,   1.7,   4.4,   3.3,
#         -0.5,   5. ,   1.4,   3. ,   6.7,   2.2,   0.2,   6.2,   4.6,
#          4.2,  -6.2,  -2.3,   6.1,   7.5,  -0.1,   2.8,   1.2,   3.9,
#          3.4,   5.9,  38.4,  -1.5,   2.9,  -0.3,   6.3,  -2.7,   0.7,
#          2.6,  -0.6,   0.5,  12.5,  -0.2,  -0.4,  74.4,   8.1,   5.1,
#          3.2,   2.4,   0.8,   0.6,   1.1,   4.1,  -0.7,   4.9,   8. ,
#          0.9,   3.5, -18.3,   6.5,   5.2,   1.5,   5.4,   4.7])

# %%
# Histogram of Age
plt.figure(figsize=(8, 6))
sns.histplot(data['2023'], bins=20, kde=True, color='purple')
plt.show()

# %%
data['2023'].value_counts()
# Out:
# 2023
#  4.0    9
#  2.0    8
#  3.0    7
#  2.5    7
#  4.5    6
#        ..
# -0.3    1
#  6.3    1
# -2.7    1
#  0.7    1
#  4.7    1
# Name: count, Length: 79, dtype: int64

# %%
data['2023'].value_counts().plot(kind='pie', autopct="%5.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='2023', y='2024', data=data)
plt.title('Relationship between 2023 and 2024')
plt.xlabel('2023')
plt.ylabel('2024')
plt.show()

# %%
sns.histplot(x='2023', y='2024', data=data)
# Out:
# <Axes: xlabel='2023', ylabel='2024'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='2023', y='2024', data=data, color='brown')
# Out:
# <Axes: xlabel='2023', ylabel='2024'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='2023', y='2024', data=data, color='darkgreen')
plt.title('Relationship between 2023 and 2024')
plt.xlabel('2023, or hopeless?')
plt.ylabel('2024')
plt.show()
